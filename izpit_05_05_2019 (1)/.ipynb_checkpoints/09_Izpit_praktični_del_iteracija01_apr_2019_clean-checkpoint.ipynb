# %% [markdown]
# # Praktični izpit tečaja Analitika podatkov v Python-u

# %% [markdown]
# Čas reševanja: `120 min`

# %% [markdown]
# Skupno število točk: `70 pts`
#
# Odgovore na vprašanja vnesite v celice z komentarjem `# Odgovor`
#
# Za vsa vprašanja smo na voljo.
#
# Lahko si pomagate z uporabo gradiv in internetom. Ne pozabite na uradno dokumentacijo.
#
# Srečno!!

# %% [markdown]
# **Pred začetkom izpita zaženite spodnjo celico:**

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## DEL 1 - Priprava (30 pts)

# %% [markdown]
# ### 1.1) Uvoz podatkov
#
# `2 pts`

# %% [markdown]
# Pridobili smo podatke registracije avtomobilov v Sloveniji za marec 2019. Datoteka se imenuje `DATA_vozila_marec_clean1.csv`.
#
# V spodnji spremenljivki je shranjena pot do datoteke. Naložite podatke v pandas dataframe, da jih lako uporabimo za nadaljno obdelavo.

# %%
path = 'data/DATA_vozila_RAW.csv'
# !head -n 3 data/DATA_vozila_RAW.csv
# Out:
# ;Unnamed: 0;Datum prve registracije vozila;Registrsko obmocje tablice prve registracije;Starost uporabnika vozila;Spol uporabnika;Upravna enota uporabnika vozila;Znamka;Drzava (koda);Masa vozila;Kategorija in vrsta vozila (opis);Nazivna moc;Vrsta goriva (opis);P.1.5-Oznaka motorja;S.1-Stevilo sedezev (vkljucno z vozniskim);T-Najvisja hitrost;V.8-Kombinirana poraba goriva;Homologacijska;Dvtredu;Leto izdelave
# 0;0;24.10.2007;KR?KO;61.0;M;2;BMW;DEU;223;motorno kolo;80;Bencin;122EF;2.0;215.0;;;;2007
# 1;1;25.03.2019;MURSKA SOBOTA;58.0;Z;36;FIAT;ITA;1270;osebni avtomobil;70;Bencin;843A1000;5.0;185.0;7,7;;;2019

# %%
# Odgovor
df = pd.read_csv(path, sep=';')

# %%
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Datum prve registracije vozila  \
# 0           0             0                     24.10.2007
# 1           1             1                     25.03.2019
# 2           2             2                     01.08.2008
#
#   Registrsko obmocje tablice prve registracije  Starost uporabnika vozila  \
# 0                                        KR?KO                       61.0
# 1                                MURSKA SOBOTA                       58.0
# 2                                        CELJE                       71.0
#
#   Spol uporabnika  Upravna enota uporabnika vozila Znamka Drzava (koda)  \
# 0               M                                2    BMW           DEU
# 1               Z                               36   FIAT           ITA
# 2               M                               59  HONDA           JPN
#
#   Masa vozila Kategorija in vrsta vozila (opis) Nazivna moc  \
# 0         223                      motorno kolo          80
# 1        1270                  osebni avtomobil          70
# 2         242                      motorno kolo          37
#
#   Vrsta goriva (opis) P.1.5-Oznaka motorja  \
# 0              Bencin                122EF
# 1              Bencin             843A1000
# 2              Bencin                PF01E
#
#    S.1-Stevilo sedezev (vkljucno z vozniskim)  T-Najvisja hitrost  \
# 0                                         2.0               215.0
# 1                                         5.0               185.0
# 2                                         2.0               160.0
#
#   V.8-Kombinirana poraba goriva Homologacijska Dvtredu  Leto izdelave
# 0                           NaN            NaN     NaN           2007
# 1                           7,7            NaN     NaN           2019
# 2                           NaN            NaN     NaN           2008

# %% [markdown]
# ### 1.2) Prikaz osnovnih lastnosti podatkov

# %% [markdown]
# #### 1.2.1) Prikažite obliko uvoženega dataframe-a
#
# `1 pts`

# %%
# Odgovor
df.shape
# Out:
# (14649, 20)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# #### 1.2.2) Prikažite tipe spremenljivk za vsak stolpec uvoženega dataframe-a
#
# `1 pts`

# %%
# Odgovor
df.dtypes
# Out:
# Unnamed: 0                                        int64
# Unnamed: 0.1                                      int64
# Datum prve registracije vozila                   object
# Registrsko obmocje tablice prve registracije     object
# Starost uporabnika vozila                       float64
# Spol uporabnika                                  object
# Upravna enota uporabnika vozila                   int64
# Znamka                                           object
# Drzava (koda)                                    object
# Masa vozila                                      object
# Kategorija in vrsta vozila (opis)                object
# Nazivna moc                                      object
# Vrsta goriva (opis)                              object
# P.1.5-Oznaka motorja                             object
# S.1-Stevilo sedezev (vkljucno z vozniskim)      float64
# T-Najvisja hitrost                              float64
# V.8-Kombinirana poraba goriva                    object
# Homologacijska                                   object
# Dvtredu                                          object
# Leto izdelave                                     int64
# dtype: object

# %% [markdown]
# #### 1.2.3) Prikažite prvih 7 vrstic uvoženega dataframe-a
#
# `1 pts`

# %%
# Odgovor

df.head(7)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Datum prve registracije vozila  \
# 0           0             0                     24.10.2007
# 1           1             1                     25.03.2019
# 2           2             2                     01.08.2008
# 3           3             3                     08.03.2019
# 4           4             4                     26.04.2011
# 5           5             5                     16.10.2015
# 6           6             6                     17.04.2015
#
#   Registrsko obmocje tablice prve registracije  Starost uporabnika vozila  \
# 0                                        KR?KO                       61.0
# 1                                MURSKA SOBOTA                       58.0
# 2                                        CELJE                       71.0
# 3                                        KRANJ                       64.0
# 4                                  NOVA GORICA                       63.0
# 5                                MURSKA SOBOTA                       56.0
# 6                                      MARIBOR                       47.0
#
#   Spol uporabnika  Upravna enota uporabnika vozila         Znamka  \
# 0               M                                2            BMW
# 1               Z                               36           FIAT
# 2               M                               59          HONDA
# 3               M                               58     DEUTZ-FAHR
# 4               Z                               37  MERCEDES BENZ
# 5               M                               36           AUDI
# 6               M                               42           AUDI
#
#   Drzava (koda) Masa vozila Kategorija in vrsta vozila (opis) Nazivna moc  \
# 0           DEU         223                      motorno kolo          80
# 1           ITA        1270                  osebni avtomobil          70
# 2           JPN         242                      motorno kolo          37
# 3           ITA        5200                           traktor          53
# 4           DEU        1435                  osebni avtomobil         103
# 5           DEU        1615                  osebni avtomobil         100
# 6           DEU        1910                  osebni avtomobil         200
#
#   Vrsta goriva (opis) P.1.5-Oznaka motorja  \
# 0              Bencin                122EF
# 1              Bencin             843A1000
# 2              Bencin                PF01E
# 3               Dizel         1000.3WTI3E3
# 4               Dizel              640.941
# 5               Dizel                  CSU
# 6               Dizel                  CRT
#
#    S.1-Stevilo sedezev (vkljucno z vozniskim)  T-Najvisja hitrost  \
# 0                                         2.0               215.0
# 1                                         5.0               185.0
# 2                                         2.0               160.0
# 3                                         1.0                40.0
# 4                                         5.0               200.0
# 5                                         5.0               215.0
# 6                                         5.0               250.0
#
#   V.8-Kombinirana poraba goriva Homologacijska  Dvtredu  Leto izdelave
# 0                           NaN            NaN      NaN           2007
# 1                           7,7            NaN      NaN           2019
# 2                           NaN            NaN      NaN           2008
# 3                           NaN            NaN  40,8-92           2019
# 4                           5,3            NaN      NaN           2011
# 5                             4            NaN      NaN           2015
# 6                           5,3            NaN      NaN           2015

# %% [markdown]
# #### 1.2.4) Prikažite zadnjih 6 vrstic uvoženega dataframe-a
#
# `1 pts`

# %%
# Odgovor

df.tail(6)
# Out:
#        Unnamed: 0  Unnamed: 0.1 Datum prve registracije vozila  \
# 14643       14643         14643                     29.03.2019
# 14644       14644         14644                     29.03.2019
# 14645       14645         14645                     18.06.2015
# 14646       14646         14646                     29.03.2019
# 14647       14647         14647                     29.03.2019
# 14648       14648         14648                     29.03.2019
#
#       Registrsko obmocje tablice prve registracije  Starost uporabnika vozila  \
# 14643                                        KRANJ                       22.0
# 14644                                        KOPER                       20.0
# 14645                                MURSKA SOBOTA                       21.0
# 14646                                      MARIBOR                       21.0
# 14647                                   NOVO MESTO                        NaN
# 14648                                      MARIBOR                       73.0
#
#       Spol uporabnika  Upravna enota uporabnika vozila         Znamka  \
# 14643               Z                               24     VOLKSWAGEN
# 14644               M                               48        RENAULT
# 14645               M                               36  MERCEDES BENZ
# 14646               Z                               50            KIA
# 14647             NaN                               38           FORD
# 14648               Z                               64          DACIA
#
#       Drzava (koda) Masa vozila Kategorija in vrsta vozila (opis) Nazivna moc  \
# 14643           DEU        1125                  osebni avtomobil          59
# 14644           FRA        1442                  osebni avtomobil          85
# 14645           DEU        1525                  osebni avtomobil         130
# 14646           SVK        1260                  osebni avtomobil        73,3
# 14647           DEU        2316                    tovorno vozilo         147
# 14648           ROM        1084                  osebni avtomobil          54
#
#       Vrsta goriva (opis) P.1.5-Oznaka motorja  \
# 14643              Bencin                  DFN
# 14644               Dizel               K9K U8
# 14645               Dizel              651.930
# 14646              Bencin                 G4LC
# 14647               Dizel                 SA2W
# 14648              Bencin               B4D E4
#
#        S.1-Stevilo sedezev (vkljucno z vozniskim)  T-Najvisja hitrost  \
# 14643                                         5.0               171.0
# 14644                                         5.0               190.0
# 14645                                         5.0               232.0
# 14646                                         5.0               183.0
# 14647                                         5.0               175.0
# 14648                                         5.0               158.0
#
#       V.8-Kombinirana poraba goriva                            Homologacijska  \
# 14643                           5,8                                       NaN
# 14644                           4,6                                       NaN
# 14645                           4,2                                       NaN
# 14646                           6,4            e4*1005/2010*1005/2010*0265*02
# 14647                           8,7  E11 55R-018151, 018152, E11 55R-0110910,
# 14648                           6,3                                       NaN
#
#       Dvtredu  Leto izdelave
# 14643       -           2019
# 14644     NaN           2019
# 14645     NaN           2015
# 14646     NaN           2019
# 14647    16,4           2019
# 14648     NaN           2019

# %% [markdown]
# #### 1.2.5) Prikažite informacije (velikost df, podatkovni tipi, pomnilnik...) uvoženega dataframe-a z uporabo ene metode
#
# `1 pts`

# %%
# Odgovor
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14649 entries, 0 to 14648
# Data columns (total 20 columns):
# Unnamed: 0                                      14649 non-null int64
# Unnamed: 0.1                                    14649 non-null int64
# Datum prve registracije vozila                  14649 non-null object
# Registrsko obmocje tablice prve registracije    14649 non-null object
# Starost uporabnika vozila                       8300 non-null float64
# Spol uporabnika                                 8300 non-null object
# Upravna enota uporabnika vozila                 14649 non-null int64
# Znamka                                          14649 non-null object
# Drzava (koda)                                   14649 non-null object
# Masa vozila                                     14649 non-null object
# Kategorija in vrsta vozila (opis)               14649 non-null object
# Nazivna moc                                     14649 non-null object
# Vrsta goriva (opis)                             14649 non-null object
# P.1.5-Oznaka motorja                            13912 non-null object
# S.1-Stevilo sedezev (vkljucno z vozniskim)      14229 non-null float64
# T-Najvisja hitrost                              14344 non-null float64
# V.8-Kombinirana poraba goriva                   12028 non-null object
# Homologacijska                                  3140 non-null object
# Dvtredu                                         4690 non-null object
# Leto izdelave                                   14649 non-null int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 2.2+ MB

# %% [markdown]
# ### 1.3) Priprava podatkov za obdelavo
#
# Pred analizo podatkov moramo naše podatke urediti in pripraviti.

# %% [markdown]
# #### 1.3.1) Odstrnjevanje nepotrebnih stolpcev
#
# Odstranite nepotrebne stolpce iz naših podatkov. Imena nepotrebnih stolpcev so shanjena v spodnji spremenljivki `to_drop`.
#
# Operacijo opravite na mestu (inplace).
#
# `2 pts`

# %%
to_drop = ['Unnamed: 0', 'Unnamed: 0.1', 'P.1.5-Oznaka motorja', 'Homologacijska', 'Dvtredu']

# %%
# Odgovor
df.drop(to_drop, axis=1, inplace=True)

# %%
df.head(3)
# Out:
#   Datum prve registracije vozila Registrsko obmocje tablice prve registracije  \
# 0                     24.10.2007                                        KR?KO
# 1                     25.03.2019                                MURSKA SOBOTA
# 2                     01.08.2008                                        CELJE
#
#    Starost uporabnika vozila Spol uporabnika  Upravna enota uporabnika vozila  \
# 0                       61.0               M                                2
# 1                       58.0               Z                               36
# 2                       71.0               M                               59
#
#   Znamka Drzava (koda) Masa vozila Kategorija in vrsta vozila (opis)  \
# 0    BMW           DEU         223                      motorno kolo
# 1   FIAT           ITA        1270                  osebni avtomobil
# 2  HONDA           JPN         242                      motorno kolo
#
#   Nazivna moc Vrsta goriva (opis)  S.1-Stevilo sedezev (vkljucno z vozniskim)  \
# 0          80              Bencin                                         2.0
# 1          70              Bencin                                         5.0
# 2          37              Bencin                                         2.0
#
#    T-Najvisja hitrost V.8-Kombinirana poraba goriva  Leto izdelave
# 0               215.0                           NaN           2007
# 1               185.0                           7,7           2019
# 2               160.0                           NaN           2008

# %% [markdown]
# #### 1.3.2) Preimenovanje imen stolpcev
#
# Preimenujte stolpce, da bo delo s podatki lažje. Preslikave imen stolpcev najdete v spodnji spremenljivki `new_names`.
#
# Operacijo opravite na mestu (inplace).
#
# `2 pts`

# %%
new_names = {'Datum prve registracije vozila': 'Prva_registracija',
             'Registrsko obmocje tablice prve registracije': 'Tablica_kraj',
             'Starost uporabnika vozila': 'Starost_vozinka',
             'Spol uporabnika': 'Spol_voznika',
             'Upravna enota uporabnika vozila': 'Upravna_enota_sifra',
             'Drzava (koda)': 'Država_proizvodnje',
             'Masa vozila': 'Masa_vozila',
             'Kategorija in vrsta vozila (opis)': 'Kategorija_vozila',
             'Nazivna moc': 'Moc',
             'Vrsta goriva (opis)': 'Gorivo',
             'S.1-Stevilo sedezev (vkljucno z vozniskim)': 'Stevilo_sedezev',
             'T-Najvisja hitrost': 'Hitrost_max',
             'V.8-Kombinirana poraba goriva': 'Poraba_goriva',
             'Leto izdelave': 'Leto_izdelave'
}

# %%
# Odgovor
df.rename(columns=new_names, inplace=True)

# %%
df.head(100)
# Out:
#    Prva_registracija    Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0         24.10.2007           KR?KO             61.0            M
# 1         25.03.2019   MURSKA SOBOTA             58.0            Z
# 2         01.08.2008           CELJE             71.0            M
# 3         08.03.2019           KRANJ             64.0            M
# 4         26.04.2011     NOVA GORICA             63.0            Z
# 5         16.10.2015   MURSKA SOBOTA             56.0            M
# 6         17.04.2015         MARIBOR             47.0            M
# 7         18.09.2015       LJUBLJANA             37.0            Z
# 8         05.06.2015       LJUBLJANA             56.0            Z
# 9         25.03.2019           KRANJ             55.0            Z
# 10        25.03.2019   MURSKA SOBOTA             52.0            M
# 11        19.03.2015       LJUBLJANA             32.0            M
# 12        30.07.2013           CELJE             59.0            M
# 13        17.07.2014           CELJE             43.0            M
# 14        25.11.2014           CELJE             41.0            M
# 15        21.03.2019     NOVA GORICA             60.0            Z
# 16        04.03.2019         MARIBOR             45.0            M
# 17        24.12.2013         MARIBOR             59.0            Z
# 18        28.03.2019       LJUBLJANA             56.0            Z
# 19        15.03.2019     NOVA GORICA             31.0            M
# 20        07.03.2019   MURSKA SOBOTA             63.0            M
# 21        15.03.2019       LJUBLJANA             77.0            M
# 22        23.03.2019       LJUBLJANA             43.0            M
# 23        01.03.2019     NOVA GORICA             32.0            M
# 24        01.03.2019           KRANJ             77.0            M
# 25        29.03.2019       LJUBLJANA             69.0            Z
# 26        28.04.2016         MARIBOR             52.0            Z
# 27        15.03.2019         MARIBOR             58.0            M
# 28        06.03.2019       LJUBLJANA             51.0            M
# 29        08.03.2019       LJUBLJANA             49.0            M
# ..               ...             ...              ...          ...
# 70        26.03.2019         MARIBOR             42.0            M
# 71        21.03.2016           CELJE             49.0            M
# 72        21.12.2016       LJUBLJANA             45.0            Z
# 73        06.05.2010       LJUBLJANA             40.0            M
# 74        21.02.2007      NOVO MESTO             35.0            M
# 75        17.05.2010           KRANJ             33.0            M
# 76        06.03.2019           KRANJ             58.0            Z
# 77        29.03.2019       LJUBLJANA             42.0            M
# 78        30.04.2013         MARIBOR             47.0            M
# 79        19.03.2019           KRANJ             55.0            M
# 80        13.03.2019       LJUBLJANA             38.0            Z
# 81        07.03.2019       LJUBLJANA             43.0            M
# 82        07.03.2019       LJUBLJANA             51.0            Z
# 83        19.03.2019      NOVO MESTO             42.0            Z
# 84        15.03.2019           CELJE             51.0            Z
# 85        22.03.2019           CELJE             69.0            M
# 86        02.03.2019         MARIBOR             37.0            Z
# 87        27.03.2019     NOVA GORICA             48.0            Z
# 88        29.03.2019     NOVA GORICA             48.0            M
# 89        22.03.2019           CELJE             47.0            M
# 90        01.02.2008  SLOVENJ GRADEC             45.0            M
# 91        13.03.2019           CELJE             42.0            M
# 92        18.03.2019           KRANJ             60.0            M
# 93        28.03.2019       LJUBLJANA             58.0            M
# 94        15.03.2019      NOVO MESTO             55.0            M
# 95        31.03.2003           KOPER             38.0            M
# 96        14.03.2019           CELJE             76.0            M
# 97        15.03.2019   MURSKA SOBOTA             68.0            M
# 98        21.03.2019     NOVA GORICA             55.0            Z
# 99        04.06.2009     NOVA GORICA             54.0            M
#
#     Upravna_enota_sifra           Znamka Država_proizvodnje Masa_vozila  \
# 0                     2              BMW                DEU         223
# 1                    36             FIAT                ITA        1270
# 2                    59            HONDA                JPN         242
# 3                    58       DEUTZ-FAHR                ITA        5200
# 4                    37    MERCEDES BENZ                DEU        1435
# 5                    36             AUDI                DEU        1615
# 6                    42             AUDI                DEU        1910
# 7                    24    MERCEDES BENZ                DEU        1420
# 8                    24    MERCEDES BENZ                DEU        1395
# 9                    53           SUZUKI                HUN        1270
# 10                   22          PEUGEOT                FRA        1629
# 11                   24       VOLKSWAGEN                DEU        1541
# 12                    3       VOLKSWAGEN                DEU        1601
# 13                    3    MERCEDES BENZ                DEU        1885
# 14                    3              BMW                DEU        1575
# 15                   37            ?KODA                CZE        1348
# 16                   65            ?KODA                CZE        1348
# 17                   21             OPEL                DEU        1571
# 18                   24           SUZUKI                HUN        1290
# 19                    1           YAMAHA                FRA         195
# 20                   36            HONDA                JPN        1312
# 21                   24            ADRIA                SVN        3036
# 22                   24  ANTONIO CARRARO                ITA        1670
# 23                   11            HONDA                JPN        1324
# 24                   14          HYUNDAI                TUR        1236
# 25                   48             AUDI                DEU        1165
# 26                   50       VOLKSWAGEN                DEU        1673
# 27                   21       VOLKSWAGEN                DEU        1725
# 28                   24          CITROEN                FRA        1594
# 29                   24              BMW                DEU         249
# ..                  ...              ...                ...         ...
# 70                   42           TOYOTA                JPN        1700
# 71                   52            VOLVO                SWE        1594
# 72                   24    MERCEDES BENZ                DEU        1535
# 73                   38           SUBARU                JPN        1665
# 74                   38    MERCEDES BENZ                DEU        1980
# 75                   14            MAZDA                JPN        1575
# 76                   44            DACIA                ROM        1084
# 77                   15             OPEL                DEU        2033
# 78                   42              BMW                DEU        1790
# 79                   18             SEAT                ESP        1271
# 80                   24           NISSAN                GBR        1465
# 81                   60          CITROEN                FRA        1644
# 82                   24          RENAULT                FRA        1286
# 83                   38          RENAULT                FRA        1299
# 84                   52          RENAULT                FRA        1297
# 85                   59          RENAULT                FRA        1298
# 86                   65          RENAULT                FRA        1299
# 87                   55          RENAULT                FRA        1299
# 88                    1          RENAULT                FRA        1580
# 89                   51            VOLVO                SWE        1870
# 90                   45           YAMAHA                JPN         291
# 91                   54            FOTON                CHN        2540
# 92                   53       VOLKSWAGEN                DEU        1605
# 93                   15       VOLKSWAGEN                DEU        1350
# 94                   38          PIAGGIO                ITA         115
# 95                   17            HONDA                JPN         194
# 96                   59       VOLKSWAGEN                DEU        1395
# 97                   22             FORD                DEU        1152
# 98                   24             OPEL                DEU        1278
# 99                   37           SUZUKI                JPN         232
#
#               Kategorija_vozila    Moc  Gorivo  Stevilo_sedezev  Hitrost_max  \
# 94             dvokolesni moped    2,4  Bencin              2.0         45.0
# 95                 motorno kolo    111  Bencin              2.0          NaN
# 96             osebni avtomobil     85   Dizel              5.0        187.0
# 97             osebni avtomobil   62,5  Bencin              5.0        170.0
# 98             osebni avtomobil     81  Bencin              5.0        187.0
# 99                 motorno kolo     72  Bencin              2.0        230.0
#
#    Poraba_goriva  Leto_izdelave
# 0            NaN           2007
# 1            7,7           2019
# 2            NaN           2008
# 3            NaN           2019
# 4            5,3           2011
# 5              4           2015
# 6            5,3           2015
# 7              4           2015
# 8            3,6           2015
# 9            7,5           2019
# 10           5,5           2019
# 11           4,7           2015
# 12           5,2           2013
# 13           5,5           2014
# 14           4,5           2014
# 15           4,8           2019
# 16             5           2019
# 17             4           2013
# 18           7,3           2019
# 19           NaN           2019
# 20           6,6           2019
# 21           NaN           2019
# 22           NaN           2019
# 23             0           2019
# 24             5           2019
# 25           5,6           2019
# 26           5,7           2016
# 27             7           2019
# 28           7,1           2019
# 29          4,75           2019
# ..           ...            ...
# 70           5,6           2019
# 71           4,2           2016
# 72           4,2           2016
# 73           6,4           2010
# 74           8,6           2007
# 75           5,6           2010
# 76           6,3           2019
# 77           7,1           2019
# 78           5,1           2013
# 79           6,1           2019
# 80           7,1           2019
# 81           5,8           2019
# 82           6,2           2019
# 83           6,2           2019
# 84           6,2           2019
# 85           6,2           2019
# 86           6,2           2019
# 87           6,2           2019
# 88           3,9           2019
# 89           5,6           2019
# 90           NaN           2008
# 91           NaN           2019
# 92           5,7           2019
# 93           7,1           2019
# 94           2,9           2019
# 95           NaN           2003
# 96           5,6           2019
# 97             6           2019
# 98             7           2019
# 99           NaN           2009
#
# [100 rows x 15 columns]

# %% [markdown]
# #### 1.3.3) Odstranjevenje mankajočih vrednosti
#
# Izpiši število mankajočih vrednosti za vsak stolpec v pandas Series obliki.
#
# Pričakovan odgovor:
# ```
# Prva_registracija         0
# Tablica_kraj              0
# Starost_vozinka        6349
# Spol_voznika           6349
# Upravna_enota_sifra       0
# Znamka                    0
# Država_proizvodnje        0
# Masa_vozila               0
# ...
# ```
#
# `2 pts`

# %%
# Odgovor
count_nan = len(df) - df.count()
count_nan
# Out:
# Prva_registracija         0
# Tablica_kraj              0
# Starost_vozinka        6349
# Spol_voznika           6349
# Upravna_enota_sifra       0
# Znamka                    0
# Država_proizvodnje        0
# Masa_vozila               0
# Kategorija_vozila         0
# Moc                       0
# Gorivo                    0
# Stevilo_sedezev         420
# Hitrost_max             305
# Poraba_goriva          2621
# Leto_izdelave             0
# dtype: int64

# %% [markdown]
# ---

# %%
df.shape
# Out:
# (14649, 15)

# %% [markdown]
# `2 pts`

# %% [markdown]
# Odstrani vse vrstice v naših podatkih za katere ima stolpec `Starost_vozinka` manjkajoče vrednosti.
#
# Delo nadaljuj z novimi podatki.

# %%
# Odgovor

df.dropna(subset=['Starost_vozinka'], axis='rows')
# Out:
#       Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 
# 2                       59            HONDA                JPN         242
# 3                       58       DEUTZ-FAHR                ITA        5200
# 4                       37    MERCEDES BENZ                DEU        1435
# 5                       36             AUDI                DEU        1615
# 6                       42             AUDI                DEU        1910
# 7                       24    MERCEDES BENZ                DEU        1420
# 8                       24    MERCEDES BENZ                DEU        1395
# 9                       53           SUZUKI                HUN        1270
# 10                      22          PEUGEOT                FRA        1629
# 11                      24       VOLKSWAGEN                DEU        1541
# 12                       3       VOLKSWAGEN                DEU        1601
# 13                       3    MERCEDES BENZ                DEU        1885
# 14                       3              BMW                DEU        1575
# 15                      37            ?KODA                CZE        1348
# 16                      65            ?KODA                CZE        1348
# 17                      21             OPEL                DEU        1571
# 18                      24           SUZUKI                HUN        1290
# 19                       1           YAMAHA                FRA         195
# 20                      36            HONDA                JPN        1312
# 21                      24            ADRIA                SVN        3036
# 22                      24  ANTONIO CARRARO                ITA        1670
# 23                      11            HONDA                JPN        1324
# 24                      14          HYUNDAI                TUR        1236
# 25                      48             AUDI                DEU        1165
# 26                      50       VOLKSWAGEN                DEU        1673
# 27                      21       VOLKSWAGEN                DEU        1725
# 28                      24          CITROEN                FRA        1594
# 29                      24              BMW                DEU         249
# ...                    ...              ...                ...         ...
# 14602                    8          HYUNDAI                CZE        1394
# 14603                   56          RENAULT                FRA        1297
# 14606                   38             AUDI                DEU        1550
# 14607                    0       VOLKSWAGEN                DEU        2194
# 14608                   24            ?KODA                CZE        1268
# 14611                   46          HYUNDAI                KOR        1538
# 14612                    6       VOLKSWAGEN                DEU        2047
# 14615                   42          PEUGEOT                FRA        1235
# 14621                   13           NISSAN                FRA        1105
# 14622                   40    MERCEDES BENZ                DEU        1325
# 14623                   34       VOLKSWAGEN                DEU        1435
# 14624                    0              TPV                SVN         508
# 14625                    0          CITROEN                FRA        1160
# 14627                   59            DACIA                ROM        1150
# 14629                   36          HYUNDAI                CZE        1500
# 14630                    0          SCHMITZ                DEU        8722
# 14631                   53          CITROEN                FRA        1092
# 14632                   37           SUZUKI                JPN         915
# 14635                   53              BMW                DEU        1665
# 14636                    0    MERCEDES BENZ                DEU       17650
# 14637                   37              KIA                SVK        1334
# 14638                    4              KIA                SVK        1260
# 14639                   24          RENAULT                FRA        1429
# 14640                   38              BMW                DEU        1875
# 14641                   36          CITROEN                FRA        1082
# 14643                   24       VOLKSWAGEN                DEU        1125
# 14644                   48          RENAULT                FRA        1442
# 14645                   36    MERCEDES BENZ                DEU        1525
# 14646                   50              KIA                SVK        1260
# 14648                   64            DACIA                ROM        1084
#
#                  Kategorija_vozila   Moc     Gorivo  Stevilo_sedezev  \
# 0                     motorno kolo    80     Bencin              2.0
# 1                 osebni avtomobil    70     Bencin              5.0
# 2                     motorno kolo    37     Bencin              2.0
# 3                          traktor    53      Dizel              1.0
# 4                 osebni avtomobil   103      Dizel              5.0
# 5                 osebni avtomobil   100      Dizel              5.0
# 6                 osebni avtomobil   200      Dizel              5.0
# 7                 osebni avtomobil    80      Dizel              5.0
# 8                 osebni avtomobil    80      Dizel              5.0
# 9                 osebni avtomobil   103     Bencin              5.0
# 10           230.0           5,5           2019             LENDAVA
# 11           216.0           4,7           2015           LJUBLJANA
# 12           208.0           5,2           2013               CELJE
# 13           232.0           5,5           2014               CELJE
# 14           210.0           4,5           2014               CELJE
# 15           205.0           4,8           2019         NOVA GORICA
# 16           205.0             5           2019             PESNICA
# 17           186.0             4           2013              LENART
# 18           200.0           7,3           2019           LJUBLJANA
# 19           200.0           NaN           2019          AJDOVŠČINA
# 20           192.0           6,6           2019       MURSKA SOBOTA
# 21           140.0           NaN           2019           LJUBLJANA
# 22            30.0           NaN           2019           LJUBLJANA
# 23           187.0             0           2019              IDRIJA
# 24           190.0             5           2019            JESENICE
# 25           191.0           5,6           2019              SEŽANA
# 26           200.0           5,7           2016  SLOVENSKA BISTRICA
# 27           200.0             7           2019              LENART
# 28           175.0           7,1           2019           LJUBLJANA
# 29           219.0          4,75           2019           LJUBLJANA
# ...            ...           ...            ...                 ...
# 14602        188.0           5,5           2019      GORNJA RADGONA
# 14603        171.0           6,2           2019            TRBOVLJE
# 14606        250.0           8,3           2009          NOVO MESTO
# 14607        158.0           7,6           2019             Neznana
# 14608        199.0           5,8           2019           LJUBLJANA
# 14611        186.0           4,8           2019             RIBNICA
# 14612        181.0           8,6           2019             DOMŽALE
# 14615        180.0           3,7           2018                PTUJ
# 14621        158.0           4,6           2019               IZOLA
# 14622        170.0             5           2007               PIRAN
# 14623        196.0           3,6           2015             METLIKA
# 14624          NaN           NaN           2019             Neznana
# 14625        184.0           3,4           2016             Neznana
# 14627        168.0           6,6           2019             VELENJE
# 14629        176.0           4,6           2016       MURSKA SOBOTA
# 14630        100.0           NaN           2011             Neznana
# 14631        169.0           5,9           2019         ŠKOFJA LOKA
# 14632        180.0           5,1           2019         NOVA GORICA
# 14635        228.0           5,3           2011         ŠKOFJA LOKA
# 14636         90.0           NaN           2007             Neznana
# 14637        190.0           5,5           2019         NOVA GORICA
# 14638        183.0           6,4           2019            CERKNICA
# 14639        203.0           6,3           2019           LJUBLJANA
# 14640        250.0           5,5           2017          NOVO MESTO
# 14641        169.0           5,9           2019       MURSKA SOBOTA
# 14643        171.0           5,8           2019           LJUBLJANA
# 14644        190.0           4,6           2019              SEŽANA
# 14645        232.0           4,2           2015       MURSKA SOBOTA
# 14646        183.0           6,4           2019  SLOVENSKA BISTRICA
# 14648        158.0           6,3           2019             MARIBOR
#
# [8300 rows x 16 columns]

# %% [markdown]
# ---

# %% [markdown]
# `2 pts`

# %% [markdown]
# Vse manjkajoče vrednosti v stolpcu `Stevilo_sedezev` nadomesti z številom `0`.
#
# Delo nadaljuj z novimi podatki.

# %%
# Odgovor
df["Stevilo_sedezev"].fillna(0)
# Out:
# 0        2.0
# 1        5.0
# 2        2.0
# 3        1.0
# 4        5.0
# 5        5.0
# 6        5.0
# 7        5.0
# 8        5.0
# 9        5.0
# 10       5.0
# 11       5.0
# 12       5.0
# 13       5.0
# 14       5.0
# 15       5.0
# 16       5.0
# 17       5.0
# 18       5.0
# 19       2.0
# 20       5.0
# 21       5.0
# 22       1.0
# 23       5.0
# 24       5.0
# 25       5.0
# 26       5.0
# 27       5.0
# 28       5.0
# 29       2.0
#         ...
# 14619    2.0
# 14620    0.0
# 14621    5.0
# 14622    5.0
# 14623    5.0
# 14624    0.0
# 14625    5.0
# 14626    1.0
# 14627    5.0
# 14628    5.0
# 14629    5.0
# 14630    0.0
# 14631    5.0
# 14632    5.0
# 14633    5.0
# 14634    0.0
# 14635    5.0
# 14636    2.0
# 14637    5.0
# 14638    5.0
# 14639    5.0
# 14640    5.0
# 14641    5.0
# 14642    4.0
# 14643    5.0
# 14644    5.0
# 14645    5.0
# 14646    5.0
# 14647    5.0
# 14648    5.0
# Name: Stevilo_sedezev, Length: 14649, dtype: float64

# %% [markdown]
# #### 1.3.4) Iskanje podvojenih vrstic v podatkih

# %% [markdown]
# Poišči število podvojenih vrstic v naših podatkih.
#
# `1 pts`

# %%
# Odgovor

df.duplicated().sum()
# Out:
# 2275

# %% [markdown]
# ---

# %% [markdown]
# `1 pts`

# %% [markdown]
# Odstrani vse podvojene vrstice iz naših podatkov.

# %%
# Odgovor
df.drop_duplicates()
# Out:
#       Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0            24.10.2007          KR?KO             61.0            M
# 1            25.03.2019  MURSKA SOBOTA             58.0            Z
# 2            01.08.2008          CELJE             71.0            M
# 3            08.03.2019          KRANJ             64.0            M
# 4            26.04.2011    NOVA GORICA             63.0            Z
# 5            16.10.2015  MURSKA SOBOTA             56.0            M
# 6            17.04.2015        MARIBOR             47.0            M
# 7            18.09.2015      LJUBLJANA             37.0            Z
# 8            05.06.2015      LJUBLJANA             56.0            Z
# 9            25.03.2019          KRANJ             55.0            Z
# 10           25.03.2019  MURSKA SOBOTA             52.0            M
# 11           19.03.2015      LJUBLJANA             32.0            M
# 12           30.07.2013          CELJE             59.0            M
# 13           17.07.2014          CELJE             43.0            M
# 14           25.11.2014          CELJE             41.0            M
# 15           21.03.2019    NOVA GORICA             60.0            Z
# 16           04.03.2019        MARIBOR             45.0            M
# 17           24.12.2013        MARIBOR             59.0            Z
# 18           28.03.2019      LJUBLJANA             56.0            Z
# 19           15.03.2019    NOVA GORICA             31.0            M
# 20           07.03.2019  MURSKA SOBOTA             63.0            M
# 21           15.03.2019      LJUBLJANA             77.0            M
# 22           23.03.2019      LJUBLJANA             43.0            M
# 23           01.03.2019    NOVA GORICA             32.0            M
# 24           01.03.2019          KRANJ             77.0            M
# 25           29.03.2019      LJUBLJANA             69.0            Z
# 26           28.04.2016        MARIBOR             52.0            Z
# 27           15.03.2019        MARIBOR             58.0            M
# 28           06.03.2019      LJUBLJANA             51.0            M
# 29           08.03.2019      LJUBLJANA             49.0            M
# ...                 ...            ...              ...          ...
# 14619        10.03.2016          CELJE              NaN          NaN
# 14620        10.03.2016          CELJE              NaN          NaN
# 14621        26.03.2019          KOPER             28.0            Z
# 14622        17.12.2007          KOPER             20.0            Z
# 14623        23.06.2015     NOVO MESTO             26.0            Z
# 14624        26.03.2019        MARIBOR             71.0            M
# 14625        15.07.2016        MARIBOR             51.0            Z
# 14626        24.05.2010          CELJE              NaN          NaN
# 14627        26.03.2019          CELJE             50.0            M
# 14628        23.08.2016          KOPER              NaN          NaN
# 14629        20.12.2016  MURSKA SOBOTA             74.0            Z
# 14630        03.01.2011          CELJE             24.0            M
# 14631        04.03.2019          KRANJ             48.0            Z
# 14632        04.03.2019    NOVA GORICA             43.0            Z
# 14633        04.03.2019          KRANJ              NaN          NaN
# 14634        04.03.2019      LJUBLJANA              NaN          NaN
# 14635        31.08.2011          KRANJ             28.0            M
# 14636        02.08.2007          CELJE             40.0            M
# 14637        04.03.2019    NOVA GORICA             22.0            M
# 14638        04.03.2019      LJUBLJANA             33.0            M
# 14639        29.03.2019      LJUBLJANA             31.0            M
# 14640        17.10.2017      LJUBLJANA             31.0            M
# 14641        29.03.2019          KRANJ             32.0            Z
# 14642        29.03.2019      LJUBLJANA              NaN          NaN
# 14643        29.03.2019          KRANJ             22.0            Z
# 14644        29.03.2019          KOPER             20.0            M
# 14645        18.06.2015  MURSKA SOBOTA             21.0            M
# 14646        29.03.2019        MARIBOR             21.0            Z
# 14647        29.03.2019     NOVO MESTO              NaN          NaN
# 14648        29.03.2019        MARIBOR             73.0            Z
#
#        Upravna_enota_sifra           Znamka Država_proizvodnje Masa_vozila  \
# 0                        2              BMW                DEU         223
# 1                       36             FIAT                ITA        1270
# 2                       59            HONDA                JPN         242
# 3                       58       DEUTZ-FAHR                ITA        5200
# 4                       37    MERCEDES BENZ                DEU        1435
# 5                       36             AUDI                DEU        1615
# 6                       42             AUDI                DEU        1910
# 7                       24    MERCEDES BENZ                DEU        1420
# 8                       24    MERCEDES BENZ                DEU        1395
# 9                       53           SUZUKI                HUN        1270
# 10                      22          PEUGEOT                FRA        1629
# 11                      24       VOLKSWAGEN                DEU        1541
# 12                       3       VOLKSWAGEN                DEU        1601
# 13                       3    MERCEDES BENZ                DEU        1885
# 14                       3              BMW                DEU        1575
# 15                      37            ?KODA                CZE        1348
# 16                      65            ?KODA                CZE        1348
# 17                      21             OPEL                DEU        1571
# 18                      24           SUZUKI                HUN        1290
# 19                       1           YAMAHA                FRA         195
# 20                      36            HONDA                JPN        1312
# 21                      24            ADRIA                SVN        3036
# 22                      24  ANTONIO CARRARO                ITA        1670
# 23                      11            HONDA                JPN        1324
# 24                      14          HYUNDAI                TUR        1236
# 25                      48             AUDI                DEU        1165
# 26                      50       VOLKSWAGEN                DEU        1673
# 27                      21       VOLKSWAGEN                DEU        1725
# 28                      24          CITROEN                FRA        1594
# 29                      24              BMW                DEU         249
# ...                    ...              ...                ...         ...
# 14619                    3            VOLVO                SWE        8447
# 14620                    3          SCHMITZ                DEU        7022
# 14621                   13           NISSAN                FRA        1105
# 14622                   40    MERCEDES BENZ                DEU        1325
# 14623                   34       VOLKSWAGEN                DEU        1435
# 14624                    0              TPV                SVN         508
# 14625                    0          CITROEN                FRA        1160
# 14626                   54      NEW HOLLAND                LUX        3550
# 14627                   59            DACIA                ROM        1150
# 14628                   24       VOLKSWAGEN                DEU        1590
# 14629                   36          HYUNDAI                CZE        1500
# 14630                    0          SCHMITZ                DEU        8722
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        24.10.2007          KR?KO             61.0            M
# 1        25.03.2019  MURSKA SOBOTA             58.0            Z
# 2        01.08.2008          CELJE             71.0            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje Masa_vozila  \
# 0                    2    BMW                DEU         223
# 1                   36   FIAT                ITA        1270
# 2                   59  HONDA                JPN         242
#
#   Kategorija_vozila Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80  Bencin              2.0        215.0           NaN
# 1  osebni avtomobil  70  Bencin              5.0        185.0           7,7
# 2      motorno kolo  37  Bencin              2.0        160.0           NaN
#
#    Leto_izdelave
# 0           2007
# 1           2019
# 2           2008

# %% [markdown]
# Stolpec `Upravna_enota_sifra` vsebuje šifre upravnih enot. Spodaj je podan slovar, ki preslika šifro upravne enote v njeno ime. Dodajte stolpec `Upravna_enota` v katerem so preslikana imena upravnih enot.
#
# Nadaljujte delo z novimi podatki.
#
# Namig: Uporabite pandas metodo .map()
#
# `2 pts`

# %%
sifra_to_ime = {0: "Neznana",
              1: "AJDOVŠČINA",
              2: "BREŽICE",
              3: "CELJE",
              4: "CERKNICA",
              5: "ČRNOMELJ",
              6: "DOMŽALE",
              7: "DRAVOGRAD",
              8: "GORNJA RADGONA",
              9: "GROSUPLJE",
              10: "HRASTNIK",
              11: "IDRIJA",
              12: "ILIRSKA BISTRICA",
              13: "IZOLA",
              14: "JESENICE",
              15: "KAMNIK",
              16: "KOČEVJE",
              17: "KOPER",
              18: "KRANJ",
              19: "KRŠKO",
              20: "LAŠKO",
              21: "LENART",
              22: "LENDAVA",
              23: "LITIJA",
              24: "LJUBLJANA",
              29: "LJUTOMER",
              30: "LOGATEC",
              34: "METLIKA",
              35: "MOZIRJE",
              36: "MURSKA SOBOTA",
              37: "NOVA GORICA",
              38: "NOVO MESTO",
              39: "ORMOŽ",
              40: "PIRAN",
              41: "POSTOJNA",
              42: "PTUJ",
              43: "RADLJE OB DRAVI",
              44: "RADOVLJICA",
              45: "RAVNE NA KOROŠKEM",
              46: "RIBNICA",
              47: "SEVNICA",
              48: "SEŽANA",
              49: "SLOVENJ GRADEC",
              50: "SLOVENSKA BISTRICA",
              51: "SLOVENSKE KONJICE",
              52: "ŠENTJUR PRI CELJU",
              53: "ŠKOFJA LOKA",
              54: "ŠMARJE PRI JELŠAH",
              55: "TOLMIN",
              56: "TRBOVLJE",
              57: "TREBNJE",
              58: "TRŽIČ",
              59: "VELENJE",
              60: "VRHNIKA",
              61: "ZAGORJE OB SAVI",
              62: "ŽALEC",
              64: "MARIBOR",
              65: "PESNICA",
              68: "RUŠE"}

# %%
# Odgovor

df['Upravna_enota'] = df['Upravna_enota_sifra'].map(sifra_to_ime)
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        24.10.2007          KR?KO             61.0            M
# 1        25.03.2019  MURSKA SOBOTA             58.0            Z
# 2        01.08.2008          CELJE             71.0            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje Masa_vozila  \
# 0                    2    BMW                DEU         223
# 1                   36   FIAT                ITA        1270
# 2                   59  HONDA                JPN         242
#
#   Kategorija_vozila Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80  Bencin              2.0        215.0           NaN
# 1  osebni avtomobil  70  Bencin              5.0        185.0           7,7
# 2      motorno kolo  37  Bencin              2.0        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %% [markdown]
# #### 1.3.6) Sprememba podatkovnih tipov

# %% [markdown]
# Pretvori stolpec `Prva_registracija` v podatkovni tip `datetime64[ns]`.
#
#
# Nadaljujte delo z novimi podatki.
#
# `2 pts`

# %%
# Odgovor
df['Prva_registracija'] = pd.to_datetime(df['Prva_registracija'])
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KR?KO             61.0            M
# 1        2019-03-25  MURSKA SOBOTA             58.0            Z
# 2        2008-01-08          CELJE             71.0            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje Masa_vozila  \
# 0                    2    BMW                DEU         223
# 1                   36   FIAT                ITA        1270
# 2                   59  HONDA                JPN         242
#
#   Kategorija_vozila Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80  Bencin              2.0        215.0           NaN
# 1  osebni avtomobil  70  Bencin              5.0        185.0           7,7
# 2      motorno kolo  37  Bencin              2.0        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %% [markdown]
# ---

# %% [markdown]
# Pretvori naslednje stolpce v naslednje podatkovne tipe:
# - `Starost_vozinka` -> `int64`
# - `Masa_vozila` -> `float64` (pozor na decimalno vejico namesto decimalne pike)
# - `Moc` -> `float64` (pozor na decimalno vejico namesto decimalne pike)
# - `Stevilo_sedezev` -> `int64`
#
# Na koncu želimo imeti podatke takšne oblike:
# ```
# Prva_registracija      8298 non-null datetime64[ns]
# Tablica_kraj           8298 non-null object
# Starost_vozinka        8298 non-null int64
# Spol_voznika           8298 non-null object
# Upravna_enota_sifra    8298 non-null int64
# Znamka                 8298 non-null object
# Država_proizvodnje     8298 non-null object
# Masa_vozila            8298 non-null float64
# Kategorija_vozila      8298 non-null object
# Moc                    8298 non-null float64
# Gorivo                 8298 non-null object
# Stevilo_sedezev        8298 non-null int64
# Hitrost_max            8194 non-null float64
# Poraba_goriva          6812 non-null object
# Leto_izdelave          8298 non-null int64
# Upravna_enota          8298 non-null object
# ```

# %% [markdown]
# `4 pts`

# %%
# Odgovor
df = df.dropna(subset=['Starost_vozinka'])
df['Starost_vozinka'] = df['Starost_vozinka'].astype('int')

# %%
# Odgovor
df['Masa_vozila'] = df['Masa_vozila'].str.replace(',','').astype(np.float64)

# %%
# Odgovor
df['Moc'] = df['Moc'].str.replace(',','').astype(np.float64)

# %%
# Odgovor
df = df.dropna(subset=['Stevilo_sedezev'])
df['Stevilo_sedezev'] = df['Stevilo_sedezev'].astype('int')

# %%
df.dtypes
# Out:
# Prva_registracija      datetime64[ns]
# Tablica_kraj                   object
# Starost_vozinka                 int64
# Spol_voznika                   object
# Upravna_enota_sifra             int64
# Znamka                         object
# Država_proizvodnje             object
# Masa_vozila                   float64
# Kategorija_vozila              object
# Moc                           float64
# Gorivo                         object
# Stevilo_sedezev                 int64
# Hitrost_max                   float64
# Poraba_goriva                  object
# Leto_izdelave                   int64
# Upravna_enota                  object
# dtype: object

# %% [markdown]
# #### 1.3.7) Sprememba vrednsoti v določenih celicah

# %% [markdown]
# - V stolpcu `Tablica_kraj` imamo vrednost `KR?KO`. Kot zgleda podatek ni bil pravilno vnešen. Spremenite vse vrednosti `KR?KO` v `KRSKO`.
#
# - V stolpcu `Znamka` imamo vrednost `?KODA`. Kot zgleda podatek ni bil pravilno vnešen. Spremenite vse vrednosti `?KODA` v `SKODA`.
#
# `2 pts`

# %%
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KR?KO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2    BMW                DEU        223.0
# 1                   36   FIAT                ITA       1270.0
# 2                   59  HONDA                JPN        242.0
#
#   Kategorija_vozila   Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80.0  Bencin                2        215.0           NaN
# 1  osebni avtomobil  70.0  Bencin                5        185.0           7,7
# 2      motorno kolo  37.0  Bencin                2        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %%
# Odgovor
df.replace(['KR?KO','?KODA'],['KRSKO', 'SKODA'])
# Out:
#       Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0            2007-10-24          KRSKO               61            M
# 1            2019-03-25  MURSKA SOBOTA               58            Z
# 2            2008-01-08          CELJE               71            M
# 3            2019-08-03          KRANJ               64            M
# 4            2011-04-26    NOVA GORICA               63            Z
# 5            2015-10-16  MURSKA SOBOTA               56            M
# 6            2015-04-17        MARIBOR               47            M
# 7            2015-09-18      LJUBLJANA               37            Z
# 8            2015-05-06      LJUBLJANA               56            Z
# 9            2019-03-25          KRANJ               55            Z
# 10           2019-03-25  MURSKA SOBOTA               52            M
# 11           2015-03-19      LJUBLJANA               32            M
# 12           2013-07-30          CELJE               59            M
# 13           2014-07-17          CELJE               43            M
# 14           2014-11-25          CELJE               41            M
# 15           2019-03-21    NOVA GORICA               60            Z
# 16           2019-04-03        MARIBOR               45            M
# 17           2013-12-24        MARIBOR               59            Z
# 18           2019-03-28      LJUBLJANA               56            Z
# 19           2019-03-15    NOVA GORICA               31            M
# 20           2019-07-03  MURSKA SOBOTA               63            M
# 21           2019-03-15      LJUBLJANA               77            M
# 22           2019-03-23      LJUBLJANA               43            M
# 23           2019-01-03    NOVA GORICA               32            M
# 24           2019-01-03          KRANJ               77            M
# 25           2019-03-29      LJUBLJANA               69            Z
# 26           2016-04-28        MARIBOR               52            Z
# 27           2019-03-15        MARIBOR               58            M
# 28           2019-06-03      LJUBLJANA               51            M
# 29           2019-08-03      LJUBLJANA               49            M
# ...                 ...            ...              ...          ...
# 14601        2019-03-29      LJUBLJANA               67            Z
# 14602        2019-03-29        MARIBOR               30            Z
# 14603        2019-03-29      LJUBLJANA               27            Z
# 14606        2009-05-22          KOPER               22            M
# 14607        2019-03-15     NOVO MESTO               38            M
# 14608        2019-03-15      LJUBLJANA               34            M
# 14629        176.0           4,6           2016       MURSKA SOBOTA
# 14630        100.0           NaN           2011             Neznana
# 14631        169.0           5,9           2019         ŠKOFJA LOKA
# 14632        180.0           5,1           2019         NOVA GORICA
# 14635        228.0           5,3           2011         ŠKOFJA LOKA
# 14636         90.0           NaN           2007             Neznana
# 14637        190.0           5,5           2019         NOVA GORICA
# 14638        183.0           6,4           2019            CERKNICA
# 14639        203.0           6,3           2019           LJUBLJANA
# 14640        250.0           5,5           2017          NOVO MESTO
# 14641        169.0           5,9           2019       MURSKA SOBOTA
# 14643        171.0           5,8           2019           LJUBLJANA
# 14644        190.0           4,6           2019              SEŽANA
# 14645        232.0           4,2           2015       MURSKA SOBOTA
# 14646        183.0           6,4           2019  SLOVENSKA BISTRICA
# 14648        158.0           6,3           2019             MARIBOR
#
# [8210 rows x 16 columns]

# %% [markdown]
# ### 1.4) Izvoz urejenih podatkov

# %% [markdown]
# Pripravljene in urejene podatke izvozite v novo csv datoteko z imenom `DATA_vozila_CLEAN`. Za pot lahko uporabite pripravljano spremenljivko `path`. Za separator uporabite `,`. Indexa **ne** izvozite s podatki.
#
# `1 pts`

# %%
path = 'data/DATA_vozila_CLEAN.csv'

# %%
# Odgovor
df.to_csv('data/DATA_vozila_CLEAN_test.csv', sep=',', index=False)

# %% [markdown]
# ## DEL 2 - Analiza (40 pts)

# %% [markdown]
# V tem delu sledi analiza urejenih podatkov.

# %% [markdown]
# V primeru, da vam ni uspelo urediti podatkov v prejšnjem delu, si jih lahko naložite v pomočjo spodnje celice.

# %%
# Naložimo urejene podatke
df = pd.read_csv('data/DATA_vozila_CLEAN.csv')

# %%
df.head()
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
# 3        2019-08-03          KRANJ               64            M
# 4        2011-04-26    NOVA GORICA               63            Z
#
#    Upravna_enota_sifra         Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2            BMW                DEU        223.0
# 1                   36           FIAT                ITA       1270.0
# 2                   59          HONDA                JPN        242.0
# 3                   58     DEUTZ-FAHR                ITA       5200.0
# 4                   37  MERCEDES BENZ                DEU       1435.0
#
#   Kategorija_vozila    Moc  Gorivo  Stevilo_sedezev  Hitrost_max  \
# 0      motorno kolo   80.0  Bencin                2        215.0
# 1  osebni avtomobil   70.0  Bencin                5        185.0
# 2      motorno kolo   37.0  Bencin                2        160.0
# 3           traktor   53.0   Dizel                1         40.0
# 4  osebni avtomobil  103.0   Dizel                5        200.0
#
#   Poraba_goriva  Leto_izdelave  Upravna_enota
# 0           NaN           2007        BREŽICE
# 1           7,7           2019  MURSKA SOBOTA
# 2           NaN           2008        VELENJE
# 3           NaN           2019          TRŽIČ
# 4           5,3           2011    NOVA GORICA

# %% [markdown]
# Prikažite glavne statistične lastnosti za numerične stolpce z uporabo ene metode.
#
# `1 pts`

# %%
# Odgovor
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8298 entries, 0 to 8297
# Data columns (total 16 columns):
# Prva_registracija      8298 non-null object
# Tablica_kraj           8298 non-null object
# Starost_vozinka        8298 non-null int64
# Spol_voznika           8298 non-null object
# Upravna_enota_sifra    8298 non-null int64
# Znamka                 8298 non-null object
# Država_proizvodnje     8298 non-null object
# Masa_vozila            8298 non-null float64
# Kategorija_vozila      8298 non-null object
# Moc                    8298 non-null float64
# Gorivo                 8298 non-null object
# Stevilo_sedezev        8298 non-null int64
# Hitrost_max            8194 non-null float64
# Poraba_goriva          6812 non-null object
# Leto_izdelave          8298 non-null int64
# Upravna_enota          8298 non-null object
# dtypes: float64(3), int64(4), object(9)
# memory usage: 1.0+ MB

# %% [markdown]
# ### 2.1) Analiza - Znamke vozil `6 pts`

# %% [markdown]
# Analizirajte stolpec `Znamka`.
#
# Izpišite število registriranih števil po znamkah.
#
# `1 pts`

# %%
# Odgovor

df['Znamka'].value_counts()[:10]
# Out:
# VOLKSWAGEN       1132
# RENAULT           693
# BMW               524
# AUDI              440
# SKODA             436
# CITROEN           435
# OPEL              387
# PEUGEOT           348
# MERCEDES BENZ     293
# FORD              278
# Name: Znamka, dtype: int64

# %% [markdown]
# Prvih 10 vrednosti (10 najbolj pogostih znamk in število registaciiji) zgornjega izračuna shranite v spremenljivko `znamke_top_10`.
#
# `2 pts`

# %%
# Odgovor
znamke_top_10 = df['Znamka'].value_counts()[:10]

# %% [markdown]
# Izrišite graf števil registraciji v odvisnosti od znamk (za `znamke_top_10` Series).
#
# Uporabite funkcijo plot v knjižnjici pandas. Graf naj bo tipa `bar` z naslovom `Pogostost znamk vozil`
#
# `3 pts`

# %%
# Odgovor
znamke_top_10 = df['Znamka'].value_counts()[:10].plot(kind='barh', title='Pogostost znamk vozil')

# %% [markdown]
# ### 2.2) Analiza - Maksimalna hitrost vozila v primerjavi s spoloma `4 pts`

# %% [markdown]
# Izdelejte nov dataframe z imenom `df_osebna_spol`, v katerem shranite samo vrstice, ki predstavljajo osebna vozila (stolpec `Kategorija_vozila` -> vrednost `osebni avtomobil`).
#
# `1 pts`

# %%
# Odgovor
array = ['osebni avtomobil']
col_ = df.loc[df['Kategorija_vozila'].isin(array)]
col_.head()
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 4        2011-04-26    NOVA GORICA               63            Z
# 5        2015-10-16  MURSKA SOBOTA               56            M
# 6        2015-04-17        MARIBOR               47            M
# 7        2015-09-18      LJUBLJANA               37            Z
#
#    Upravna_enota_sifra         Znamka Država_proizvodnje  Masa_vozila  \
# 1                   36           FIAT                ITA       1270.0
# 4                   37  MERCEDES BENZ                DEU       1435.0
# 5                   36           AUDI                DEU       1615.0
# 6                   42           AUDI                DEU       1910.0
# 7                   24  MERCEDES BENZ                DEU       1420.0
#
#   Kategorija_vozila    Moc  Gorivo  Stevilo_sedezev  Hitrost_max  \
# 1  osebni avtomobil   70.0  Bencin                5        185.0
# 4  osebni avtomobil  103.0   Dizel                5        200.0
# 5  osebni avtomobil  100.0   Dizel                5        215.0
# 6  osebni avtomobil  200.0   Dizel                5        250.0
# 7  osebni avtomobil   80.0   Dizel                5        190.0
#
#   Poraba_goriva  Leto_izdelave  Upravna_enota
# 1           7,7           2019  MURSKA SOBOTA
# 4           5,3           2011    NOVA GORICA
# 5             4           2015  MURSKA SOBOTA
# 6           5,3           2015           PTUJ
# 7             4           2015      LJUBLJANA

# %%
df_osebna_spol = pd.DataFrame(col_, columns = ['Kategorija_vozila']) 
df_osebna_spol.head()
# Out:
#   Kategorija_vozila
# 1  osebni avtomobil
# 4  osebni avtomobil
# 5  osebni avtomobil
# 6  osebni avtomobil
# 7  osebni avtomobil

# %% [markdown]
# V `df_osebna_spol` shranite samo stolpca `Spol_voznika` in `Hitrost_max`. z uporabo `loc metode`.
#
# `1 pts`

# %%
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2    BMW                DEU        223.0
# 1                   36   FIAT                ITA       1270.0
# 2                   59  HONDA                JPN        242.0
#
#   Kategorija_vozila   Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80.0  Bencin                2        215.0           NaN
# 1  osebni avtomobil  70.0  Bencin                5        185.0           7,7
# 2      motorno kolo  37.0  Bencin                2        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %%
#df_osebna_spol = df[['Spol_voznika','Hitrost_max']]
#df_osebna_spol.head(3)

# %%
# Odgovor

df_osebna_spol = df.loc[:,['Spol_voznika', 'Hitrost_max']]
df_osebna_spol.head()
# Out:
#   Spol_voznika  Hitrost_max
# 0            M        215.0
# 1            Z        185.0
# 2            M        160.0
# 3            M         40.0
# 4            Z        200.0

# %% [markdown]
# Izračunajte povprečno maksimalno hitrost (stolpec `Hitrost_max`) za vsakega izmed spolov.
#
# `2 pts`

# %%
# Odgovor
df_osebna_spol['Hitrost_max'].median(axis=0)
# Out:
# 189.0

# %% [markdown]
# ### 2.3) Analiza - Primerjava moči vozil po regijah `6 pts`

# %% [markdown]
# Izdelejte nov dataframe z imenom `df_osebna_2000_naprej`, v katerem shranite samo vrstice, ki predstavljajo osebna vozila (stolpec `Kategorija_vozila` -> vrednost `osebni avtomobil`), ki so bila izdelana po letu 2000 (vključno z letom 2000, stolpec `Leto_izdelave` >= 2000).
#
# `2 pts`

# %%
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2    BMW                DEU        223.0
# 1                   36   FIAT                ITA       1270.0
# 2                   59  HONDA                JPN        242.0
#
#   Kategorija_vozila   Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80.0  Bencin                2        215.0           NaN
# 1  osebni avtomobil  70.0  Bencin                5        185.0           7,7
# 2      motorno kolo  37.0  Bencin                2        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %%
# Odgovor
df_osebna_spol = pd.DataFrame(col_, columns = ['Kategorija_vozila', 'Leto_izdelave'])
df_osebna_spol.head()
# Out:
#   Kategorija_vozila  Leto_izdelave
# 1  osebni avtomobil           2019
# 4  osebni avtomobil           2011
# 5  osebni avtomobil           2015
# 6  osebni avtomobil           2015
# 7  osebni avtomobil           2015

# %%
df.head(2)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
#
#    Upravna_enota_sifra Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2    BMW                DEU        223.0
# 1                   36   FIAT                ITA       1270.0
#
#   Kategorija_vozila   Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80.0  Bencin                2        215.0           NaN
# 1  osebni avtomobil  70.0  Bencin                5        185.0           7,7
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA

# %%
col2_ = df.loc[(df['Leto_izdelave'] >= 2000) & (df['Kategorija_vozila'] == 'osebni avtomobil')]
df_osebna_2000_naprej = pd.DataFrame(col2_, columns = ['Kategorija_vozila', 'Leto_izdelave'])
df_osebna_2000_naprej.head()
# Out:
#   Kategorija_vozila  Leto_izdelave
# 1  osebni avtomobil           2019
# 4  osebni avtomobil           2011
# 5  osebni avtomobil           2015
# 6  osebni avtomobil           2015
# 7  osebni avtomobil           2015

# %% [markdown]
# Dobljen dataframe grupirajte po stolpcu `Tablica_kraj` in izračunjte povprečno vrednost za stolpec `Moc`. Dobljen Series poimenujte `moc_povprecna`.
#
# `2 pts`

# %%
# Odgovor
moc_ = df.groupby('Tablica_kraj')['Moc'].median()
moc_povprecna = pd.Series(moc_)
moc_.head()
# Out:
# Tablica_kraj
# CC       85.0
# CD       81.0
# CELJE    81.0
# KOPER    85.0
# KRANJ    85.0
# Name: Moc, dtype: float64

# %% [markdown]
# V grafu prikažite `moc_povprecna` za vsako regijo. Uporabite graf tipa `bar`.
#
# `2 pts`

# %%
# Odgovor
moc_povprecna.plot.bar(title='Povprečna moč motorja')
plt.show()

# %% [markdown]
# ### 2.4) Analiza - Primerjava dizel/bencin za osebna vozila po letu izdelave `17 pts`

# %% [markdown]
# # Izdelejte nov dataframe z imenom `df_osebna_2009_naprej`, v katerem shranite samo vrstice, ki predstavljajo osebna vozila (stolpec `Kategorija_vozila` -> vrednost `osebni avtomobil`), ki so bila izdelana po letu 2009 (vključno z letom 2009, stolpec `Leto_izdelave` >= 2009).
#
# `2 pts`

# %%
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2    BMW                DEU        223.0
# 1                   36   FIAT                ITA       1270.0
# 2                   59  HONDA                JPN        242.0
#
#   Kategorija_vozila   Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80.0  Bencin                2        215.0           NaN
# 1  osebni avtomobil  70.0  Bencin                5        185.0           7,7
# 2      motorno kolo  37.0  Bencin                2        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %%
# Odgovor

col3_ = df.loc[(df['Leto_izdelave'] >= 2009) & (df['Kategorija_vozila'] == 'osebni avtomobil')]
df_osebna_2009_naprej = pd.DataFrame(col3_, columns = ['Kategorija_vozila', 'Leto_izdelave'])
df_osebna_2009_naprej.head()
# Out:
#   Kategorija_vozila  Leto_izdelave
# 1  osebni avtomobil           2019
# 4  osebni avtomobil           2011
# 5  osebni avtomobil           2015
# 6  osebni avtomobil           2015
# 7  osebni avtomobil           2015

# %% [markdown]
# Iz stolpca `Gorivo` izberite samo vnose, ki imajo vrednost `Bencin` ali `Dizel` in jih shranite v `df_osebna_2009_naprej`.
#
# Namig: metoda `pandas.DataFrame.isin`
#
# `2 pts`

# %%
# Odgovor
array = ['Bencin', 'Dizel']
df.loc[(df['Gorivo']).isin(array)]
df_osebna_2009_naprej = df.loc[(df['Gorivo']).isin(array)]
df_osebna_2009_naprej.head()
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
# 3        2019-08-03          KRANJ               64            M
# 4        2011-04-26    NOVA GORICA               63            Z
#
#    Upravna_enota_sifra         Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2            BMW                DEU        223.0
# 1                   36           FIAT                ITA       1270.0
# 2                   59          HONDA                JPN        242.0
# 3                   58     DEUTZ-FAHR                ITA       5200.0
# 4                   37  MERCEDES BENZ                DEU       1435.0
#
#   Kategorija_vozila    Moc  Gorivo  Stevilo_sedezev  Hitrost_max  \
# 0      motorno kolo   80.0  Bencin                2        215.0
# 1  osebni avtomobil   70.0  Bencin                5        185.0
# 2      motorno kolo   37.0  Bencin                2        160.0
# 3           traktor   53.0   Dizel                1         40.0
# 4  osebni avtomobil  103.0   Dizel                5        200.0
#
#   Poraba_goriva  Leto_izdelave  Upravna_enota
# 0           NaN           2007        BREŽICE
# 1           7,7           2019  MURSKA SOBOTA
# 2           NaN           2008        VELENJE
# 3           NaN           2019          TRŽIČ
# 4           5,3           2011    NOVA GORICA

# %%
dizel = df[df['Gorivo'] == 'Dizel']
bencin = df[df['Gorivo'] == 'Bencin']

# %%
dizel.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 3        2019-08-03          KRANJ               64            M
# 4        2011-04-26    NOVA GORICA               63            Z
# 5        2015-10-16  MURSKA SOBOTA               56            M
#
#    Upravna_enota_sifra         Znamka Država_proizvodnje  Masa_vozila  \
# 3                   58     DEUTZ-FAHR                ITA       5200.0
# 4                   37  MERCEDES BENZ                DEU       1435.0
# 5                   36           AUDI                DEU       1615.0
#
#   Kategorija_vozila    Moc Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 3           traktor   53.0  Dizel                1         40.0           NaN
# 4  osebni avtomobil  103.0  Dizel                5        200.0           5,3
# 5  osebni avtomobil  100.0  Dizel                5        215.0             4
#
#    Leto_izdelave  Upravna_enota
# 3           2019          TRŽIČ
# 4           2011    NOVA GORICA
# 5           2015  MURSKA SOBOTA

# %%
bencin.head()
# Out:
#    Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0         2007-10-24          KRSKO               61            M
# 1         2019-03-25  MURSKA SOBOTA               58            Z
# 2         2008-01-08          CELJE               71            M
# 9         2019-03-25          KRANJ               55            Z
# 18        2019-03-28      LJUBLJANA               56            Z
#
#     Upravna_enota_sifra  Znamka Država_proizvodnje  Masa_vozila  \
# 0                     2     BMW                DEU        223.0
# 1                    36    FIAT                ITA       1270.0
# 2                    59   HONDA                JPN        242.0
# 9                    53  SUZUKI                HUN       1270.0
# 18                   24  SUZUKI                HUN       1290.0
#
#    Kategorija_vozila    Moc  Gorivo  Stevilo_sedezev  Hitrost_max  \
# 0       motorno kolo   80.0  Bencin                2        215.0
# 1   osebni avtomobil   70.0  Bencin                5        185.0
# 2       motorno kolo   37.0  Bencin                2        160.0
# 9   osebni avtomobil  103.0  Bencin                5        200.0
# 18  osebni avtomobil  103.0  Bencin                5        200.0
#
#    Poraba_goriva  Leto_izdelave  Upravna_enota
# 0            NaN           2007        BREŽICE
# 1            7,7           2019  MURSKA SOBOTA
# 2            NaN           2008        VELENJE
# 9            7,5           2019    ŠKOFJA LOKA
# 18           7,3           2019      LJUBLJANA

# %%
total_ = df.pivot_table('Prva_registracija', columns='Gorivo', aggfunc=sum)
total_
# Out:
# Gorivo                                                        Bencin  \
# Prva_registracija  2007-10-242019-03-252008-01-082019-03-252019-0...
#
# Gorivo                               Bencin/Komp. zem. plin  \
# Prva_registracija  2014-07-162002-04-042012-04-062014-02-05
#
# Gorivo                                       Bencin/Utek. naft. plin  \
# Prva_registracija  2019-07-032007-05-072006-07-022014-12-162010-1...
#
# Gorivo                                                         Dizel  \
# Prva_registracija  2019-08-032011-04-262015-10-162015-04-172015-0...
#
# Gorivo            Dizel/Utek. naft. plin.      Komprimiran zemeljski plin  \
# Prva_registracija              2010-05-19  2013-07-302019-06-032012-07-31
#
# Gorivo                                                      Me?anica  \
# Prva_registracija  2019-03-302019-03-202019-03-272019-03-292019-0...
#
# Gorivo            Neznana vrednost  \
# Prva_registracija       2019-03-13
#
# Gorivo                                                     Ni goriva
# Prva_registracija  2003-03-311992-09-182019-06-032019-07-032019-0...

# %%
grup = df.groupby('Leto_izdelave')['Gorivo'].count()
grup.head(10)
# Out:
# Leto_izdelave
# 1952    1
# 1953    1
# 1957    1
# 1958    1
# 1961    1
# 1964    2
# 1966    1
# 1967    1
# 1968    1
# 1969    2
# Name: Gorivo, dtype: int64

# %% [markdown]
# Podatke grupirajte glede na `Leto_izdelave` in `Gorivo`.  Pridobite število vrednosti za posamezno kategorijo in podatke preoblikujte nazaj v tabelo (npr. s pomočjo metode `unstack()`).
#
# Dobljen dataframe shranite v spremenljivko `count_gorivo`.
#
# Želen rezultat:
#
# <img width=200 src="./data/table_1.PNG">
#
# `3 pts`

# %%
# Odgovor
df.unstack('Leto_izdelave','Gorivo')
# Out:
# Prva_registracija  0               2007-10-24
#                    1               2019-03-25
#                    2               2008-01-08
#                    3               2019-08-03
#                    4               2011-04-26
#                    5               2015-10-16
#                    6               2015-04-17
#                    7               2015-09-18
#                    8               2015-05-06
#                    9               2019-03-25
#                    10              2019-03-25
#                    11              2015-03-19
#                    12              2013-07-30
#                    13              2014-07-17
#                    14              2014-11-25
#                    15              2019-03-21
#                    16              2019-04-03
#                    17              2013-12-24
#                    18              2019-03-28
#                    19              2019-03-15
#                    20              2019-07-03
#                    21              2019-03-15
#                    22              2019-03-23
#                    23              2019-01-03
#                    24              2019-01-03
#                    25              2019-03-29
#                    26              2016-04-28
#                    27              2019-03-15
#                    28              2019-06-03
#                    29              2019-08-03
#                                   ...
# Upravna_enota      8268        GORNJA RADGONA
#                    8269              TRBOVLJE
#                    8270            NOVO MESTO
#                    8271               Neznana
#                    8272             LJUBLJANA
#                    8273               RIBNICA
#                    8274               DOMŽALE
#                    8275                  PTUJ
#                    8276                 IZOLA
#                    8277                 PIRAN
#                    8278               METLIKA
#                    8279               Neznana
#                    8280               Neznana
#                    8281               VELENJE
#                    8282         MURSKA SOBOTA
#                    8283               Neznana
#                    8284           ŠKOFJA LOKA
#                    8285           NOVA GORICA
#                    8286           ŠKOFJA LOKA
#                    8287               Neznana
#                    8288           NOVA GORICA
#                    8289              CERKNICA
#                    8290             LJUBLJANA
#                    8291            NOVO MESTO
#                    8292         MURSKA SOBOTA
#                    8293             LJUBLJANA
#                    8294                SEŽANA
#                    8295         MURSKA SOBOTA
#                    8296    SLOVENSKA BISTRICA
#                    8297               MARIBOR
# Length: 132768, dtype: object

# %% [markdown]
# Preoblikujte dobljene podatke (`count_gorivo`) v obliko primerno za izrisovanje grafa tipa bar.

# %% [markdown]
# Prvi korak: Preoblikujte podatke s pomočjo stack metode.
#
# `1 pts`

# %%
# Odgovor
df.stack()
# Out:
# 0     Prva_registracija              2007-10-24
#       Tablica_kraj                        KRSKO
#       Starost_vozinka                        61
#       Spol_voznika                            M
#       Upravna_enota_sifra                     2
#       Znamka                                BMW
#       Država_proizvodnje                    DEU
#       Masa_vozila                           223
#       Kategorija_vozila            motorno kolo
#       Moc                                    80
#       Gorivo                             Bencin
#       Stevilo_sedezev                         2
#       Hitrost_max                           215
#       Leto_izdelave                        2007
#       Upravna_enota                     BREŽICE
# 1     Prva_registracija              2019-03-25
#       Tablica_kraj                MURSKA SOBOTA
#       Starost_vozinka                        58
#       Spol_voznika                            Z
#       Upravna_enota_sifra                    36
#       Znamka                               FIAT
#       Država_proizvodnje                    ITA
#       Masa_vozila                          1270
#       Kategorija_vozila        osebni avtomobil
#       Moc                                    70
#       Gorivo                             Bencin
#       Stevilo_sedezev                         5
#       Hitrost_max                           185
#       Poraba_goriva                         7,7
#       Leto_izdelave                        2019
#                                     ...
# 8296  Starost_vozinka                        21
#       Spol_voznika                            Z
#       Upravna_enota_sifra                    50
#       Znamka                                KIA
#       Država_proizvodnje                    SVK
#       Masa_vozila                          1260
#       Kategorija_vozila        osebni avtomobil
#       Moc                                  73.3
#       Gorivo                             Bencin
#       Stevilo_sedezev                         5
#       Hitrost_max                           183
#       Poraba_goriva                         6,4
#       Leto_izdelave                        2019
#       Upravna_enota          SLOVENSKA BISTRICA
# 8297  Prva_registracija              2019-03-29
#       Tablica_kraj                      MARIBOR
#       Starost_vozinka                        73
#       Spol_voznika                            Z
#       Upravna_enota_sifra                    64
#       Znamka                              DACIA
#       Država_proizvodnje                    ROM
#       Masa_vozila                          1084
#       Kategorija_vozila        osebni avtomobil
#       Moc                                    54
#       Gorivo                             Bencin
#       Stevilo_sedezev                         5
#       Hitrost_max                           158
#       Poraba_goriva                         6,3
#       Leto_izdelave                        2019
#       Upravna_enota                     MARIBOR
# Length: 131178, dtype: object

# %% [markdown]
# Drugi korak: Dobljenemu Series objektu dodelite ime `total` s pomočjo name metode.
#
# `1 pts`

# %%
# Odgovor
df.name = 'total'

# %% [markdown]
# Tretji korak: Restirajte indexe dobljenemu objektu.
#
# `1 pts`

# %%
# Odgovor
df.reset_index
# Out:
# <bound method DataFrame.reset_index of      Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0           2007-10-24          KRSKO               61            M
# 1           2019-03-25  MURSKA SOBOTA               58            Z
# 2           2008-01-08          CELJE               71            M
# 3           2019-08-03          KRANJ               64            M
# 4           2011-04-26    NOVA GORICA               63            Z
# 5           2015-10-16  MURSKA SOBOTA               56            M
# 6           2015-04-17        MARIBOR               47            M
# 7           2015-09-18      LJUBLJANA               37            Z
# 8           2015-05-06      LJUBLJANA               56            Z
# 9           2019-03-25          KRANJ               55            Z
# 10          2019-03-25  MURSKA SOBOTA               52            M
# 11          2015-03-19      LJUBLJANA               32            M
# 12          2013-07-30          CELJE               59            M
# 13          2014-07-17          CELJE               43            M
# 14          2014-11-25          CELJE               41            M
# 15          2019-03-21    NOVA GORICA               60            Z
# 16          2019-04-03        MARIBOR               45            M
# 17          2013-12-24        MARIBOR               59            Z
# 18          2019-03-28      LJUBLJANA               56            Z
# 19          2019-03-15    NOVA GORICA               31            M
# 20          2019-07-03  MURSKA SOBOTA               63            M
# 21          2019-03-15      LJUBLJANA               77            M
# 22          2019-03-23      LJUBLJANA               43            M
# 23          2019-01-03    NOVA GORICA               32            M
# 24          2019-01-03          KRANJ               77            M
# 25          2019-03-29      LJUBLJANA               69            Z
# 26          2016-04-28        MARIBOR               52            Z
# 27          2019-03-15        MARIBOR               58            M
# 28          2019-06-03      LJUBLJANA               51            M
# 29          2019-08-03      LJUBLJANA               49            M
# ...                ...            ...              ...          ...
# 8268        2019-03-29        MARIBOR               30            Z
# 8269        2019-03-29      LJUBLJANA               27            Z
# 8270        2009-05-22          KOPER               22            M
# 8271        2019-03-15     NOVO MESTO               38            M
# 8272        2019-03-15      LJUBLJANA               34            M
# 8273        2019-03-15      LJUBLJANA               50            Z
# 8274        2019-03-15      LJUBLJANA               36            Z
# 8275        2018-03-30          CELJE               40            Z
# 8276        2019-03-26          KOPER               28            Z
# 8277        2007-12-17          KOPER               20            Z
# 8278        2015-06-23     NOVO MESTO               26            Z
# 8279        2019-03-26        MARIBOR               71            M
# 8280        2016-07-15        MARIBOR               51            Z
# 8281        2019-03-26          CELJE               50            M
# 8282        2016-12-20  MURSKA SOBOTA               74            Z
# 8283        2011-03-01          CELJE               24            M
# 8284        2019-04-03          KRANJ               48            Z
# 8285        2019-04-03    NOVA GORICA               43            Z
# 8286        2011-08-31          KRANJ               28            M
# 8287        2007-02-08          CELJE               40            M
# 8288        2019-04-03    NOVA GORICA               22            M
# 8289        2019-04-03      LJUBLJANA               33            M
# 8290        2019-03-29      LJUBLJANA               31            M
# 8291        2017-10-17      LJUBLJANA               31            M
# 8292        2019-03-29          KRANJ               32            Z
# 8293        2019-03-29          KRANJ               22            Z
# 8294        2019-03-29          KOPER               20            M
# 8295        2015-06-18  MURSKA SOBOTA               21            M
# 8296        2019-03-29        MARIBOR               21            Z
# 8297        2019-03-29        MARIBOR               73            Z
#
#       Upravna_enota_sifra           Znamka Država_proizvodnje  Masa_vozila  \
# 0                       2              BMW                DEU        223.0
# 1                      36             FIAT                ITA       1270.0
# 2                      59            HONDA                JPN        242.0
# 3                      58       DEUTZ-FAHR                ITA       5200.0
# 4                      37    MERCEDES BENZ                DEU       1435.0
# 5                      36             AUDI                DEU       1615.0
# 6                      42             AUDI                DEU       1910.0
# 7                      24    MERCEDES BENZ                DEU       1420.0
# 8                      24    MERCEDES BENZ                DEU       1395.0
# 9                      53           SUZUKI                HUN       1270.0
# 10                     22          PEUGEOT                FRA       1629.0
# 11                     24       VOLKSWAGEN                DEU       1541.0
# 12                      3       VOLKSWAGEN                DEU       1601.0
# 13                      3    MERCEDES BENZ                DEU       1885.0
# 14                      3              BMW                DEU       1575.0
# 15                     37            SKODA                CZE       1348.0
# 16                     65            SKODA                CZE       1348.0
# 17                     21             OPEL                DEU       1571.0
# 18                     24           SUZUKI                HUN       1290.0
# 19                      1           YAMAHA                FRA        195.0
# 20                     36            HONDA                JPN       1312.0
# 21                     24            ADRIA                SVN       3036.0
# 22                     24  ANTONIO CARRARO                ITA       1670.0
# 23                     11            HONDA                JPN       1324.0
# 24                     14          HYUNDAI                TUR       1236.0
# 25                     48             AUDI                DEU       1165.0
# 26                     50       VOLKSWAGEN                DEU       1673.0
# 27                     21       VOLKSWAGEN                DEU       1725.0
# 28                     24          CITROEN                FRA       1594.0
# 29                     24              BMW                DEU        249.0
# ...                   ...              ...                ...          ...
# 8268                    8          HYUNDAI                CZE       1394.0
# 8269                   56          RENAULT                FRA       1297.0
# 8270                   38             AUDI                DEU       1550.0
# 8271                    0       VOLKSWAGEN                DEU       2194.0
# 8272                   24            SKODA                CZE       1268.0
# 8273                   46          HYUNDAI                KOR       1538.0
# 8274                    6       VOLKSWAGEN                DEU       2047.0
# 8275                   42          PEUGEOT                FRA       1235.0
# 8276                   13           NISSAN                FRA       1105.0
# 8277                   40    MERCEDES BENZ                DEU       1325.0
# 8278                   34       VOLKSWAGEN                DEU       1435.0
# 8279                    0              TPV                SVN        508.0
# 8280                    0          CITROEN                FRA       1160.0
# 8281                   59            DACIA                ROM       1150.0
# 8282                   36          HYUNDAI                CZE       1500.0
# 8285             osebni avtomobil   66.0     Bencin                5
# 8286             osebni avtomobil  135.0      Dizel                5
# 8287               tovorno vozilo  300.0      Dizel                2
# 8288             osebni avtomobil   88.3     Bencin                5
# 8289             osebni avtomobil   73.3     Bencin                5
# 8290             osebni avtomobil  103.0     Bencin                5
# 8291             osebni avtomobil  195.0      Dizel                5
# 8292             osebni avtomobil   61.0     Bencin                5
# 8293             osebni avtomobil   59.0     Bencin                5
# 8294             osebni avtomobil   85.0      Dizel                5
# 8295             osebni avtomobil  130.0      Dizel                5
# 8296             osebni avtomobil   73.3     Bencin                5
# 8297             osebni avtomobil   54.0     Bencin                5
#
#       Hitrost_max Poraba_goriva  Leto_izdelave       Upravna_enota
# 0           215.0           NaN           2007             BREŽICE
# 1           185.0           7,7           2019       MURSKA SOBOTA
# 2           160.0           NaN           2008             VELENJE
# 3            40.0           NaN           2019               TRŽIČ
# 4           200.0           5,3           2011         NOVA GORICA
# 5           215.0             4           2015       MURSKA SOBOTA
# 6           250.0           5,3           2015                PTUJ
# 7           190.0             4           2015           LJUBLJANA
# 8           190.0           3,6           2015           LJUBLJANA
# 9           200.0           7,5           2019         ŠKOFJA LOKA
# 10          230.0           5,5           2019             LENDAVA
# 11          216.0           4,7           2015           LJUBLJANA
# 12          208.0           5,2           2013               CELJE
# 13          232.0           5,5           2014               CELJE
# 14          210.0           4,5           2014               CELJE
# 15          205.0           4,8           2019         NOVA GORICA
# 16          205.0             5           2019             PESNICA
# 17          186.0             4           2013              LENART
# 18          200.0           7,3           2019           LJUBLJANA
# 19          200.0           NaN           2019          AJDOVŠČINA
# 20          192.0           6,6           2019       MURSKA SOBOTA
# 21          140.0           NaN           2019           LJUBLJANA
# 22           30.0           NaN           2019           LJUBLJANA
# 23          187.0             0           2019              IDRIJA
# 24          190.0             5           2019            JESENICE
# 25          191.0           5,6           2019              SEŽANA
# 26          200.0           5,7           2016  SLOVENSKA BISTRICA
# 27          200.0             7           2019              LENART
# 28          175.0           7,1           2019           LJUBLJANA
# 29          219.0          4,75           2019           LJUBLJANA
# ...           ...           ...            ...                 ...
# 8268        188.0           5,5           2019      GORNJA RADGONA
# 8269        171.0           6,2           2019            TRBOVLJE
# 8270        250.0           8,3           2009          NOVO MESTO
# 8271        158.0           7,6           2019             Neznana
# 8272        199.0           5,8           2019           LJUBLJANA
# 8273        186.0           4,8           2019             RIBNICA
# 8274        181.0           8,6           2019             DOMŽALE
# 8275        180.0           3,7           2018                PTUJ
# 8276        158.0           4,6           2019               IZOLA
# 8277        170.0             5           2007               PIRAN
# 8278        196.0           3,6           2015             METLIKA
# 8279          NaN           NaN           2019             Neznana
# 8280        184.0           3,4           2016             Neznana
# 8281        168.0           6,6           2019             VELENJE
# 8282        176.0           4,6           2016       MURSKA SOBOTA
# 8283        100.0           NaN           2011             Neznana
# 8284        169.0           5,9           2019         ŠKOFJA LOKA
# 8285        180.0           5,1           2019         NOVA GORICA
# 8286        228.0           5,3           2011         ŠKOFJA LOKA
# 8287         90.0           NaN           2007             Neznana
# 8288        190.0           5,5           2019         NOVA GORICA
# 8289        183.0           6,4           2019            CERKNICA
# 8290        203.0           6,3           2019           LJUBLJANA
# 8291        250.0           5,5           2017          NOVO MESTO
# 8292        169.0           5,9           2019       MURSKA SOBOTA
# 8293        171.0           5,8           2019           LJUBLJANA
# 8294        190.0           4,6           2019              SEŽANA
# 8295        232.0           4,2           2015       MURSKA SOBOTA
# 8296        183.0           6,4           2019  SLOVENSKA BISTRICA
# 8297        158.0           6,3           2019             MARIBOR
#
# [8298 rows x 16 columns]>

# %% [markdown]
# Pred izrisom podatkov, moramo podatke normalizirati. Možen postopek:
# - napišete lastno funkcijo, ki normalizira posamezno skupino podatkov
# - `count_gorivo` razvrstite glede na leto izdelave in nad vsako vrstico zaženete normalizacijsko funkcijo
#
# `4 pts`

# %%
# Odgovor

# %% [markdown]
# Namig (možne so tudi druge rešitve):
#
# > S pomočjo funkcije `sns.barplot` izrišite graf za urejene podatke.
# - na osi x prikažite `Leto_izdelave`
# - na osi y prikažite `normed_total`
# - `hue` vrednost naj predstavlja `Gorivo`
#
# Želen graf:
#
# <img width=300 src="./data/slika6.PNG">
#
# `3 pts`

# %%
# Odgovor

sns.barplot(data=df, x="Leto_izdelave", y="normed_total", hue="Gorivo")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-fecd154bc230> in <module>
#       1 # Odgovor
#       2
# ----> 3 sns.barplot(data=df, x="Leto_izdelave", y="normed_total", hue="Gorivo")
#       4
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'normed_total'

# %% [markdown]
# ### 2.5) Analiza - Korelacija moč/maksimalna hitrost `6 pts`

# %% [markdown]
# Izračunajte koorelacijsko matriko za numerične vrednsoti v naših podatkih.
#
# `1 pts`

# %%
# Odgovor
df_corr = df.corr(method ='pearson')
df_corr
# Out:
#                      Starost_vozinka  Upravna_enota_sifra  Masa_vozila  \
# Starost_vozinka             1.000000            -0.009295    -0.004022
# Upravna_enota_sifra        -0.009295             1.000000    -0.026427
# Masa_vozila                -0.004022            -0.026427     1.000000
# Moc                        -0.068173            -0.038365     0.412120
# Stevilo_sedezev             0.017011            -0.020637     0.161128
# Hitrost_max                -0.072182            -0.020972    -0.049158
# Leto_izdelave               0.135365             0.006156    -0.067788
#
#                           Moc  Stevilo_sedezev  Hitrost_max  Leto_izdelave
# Starost_vozinka     -0.068173         0.017011    -0.072182       0.135365
# Upravna_enota_sifra -0.038365        -0.020637    -0.020972       0.006156
# Masa_vozila          0.412120         0.161128    -0.049158      -0.067788
# Moc                  1.000000         0.554610     0.733135      -0.027786
# Stevilo_sedezev      0.554610         1.000000     0.666847       0.136521
# Hitrost_max          0.733135         0.666847     1.000000      -0.012056
# Leto_izdelave       -0.027786         0.136521    -0.012056       1.000000

# %% [markdown]
# Katere dve spremenljivki sta najbolj povezani?
#
# `1 pts`

# %%
# Odgovor - ni potreben izračun
df_corr.iloc[0,1]
# Out:
# -0.009294545858090504

# %%
corr_matrix = df.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
#                      Starost_vozinka  Upravna_enota_sifra  Masa_vozila  \
# Starost_vozinka                  NaN             0.009295     0.004022
# Upravna_enota_sifra              NaN                  NaN     0.026427
# Masa_vozila                      NaN                  NaN          NaN
# Moc                              NaN                  NaN          NaN
# Stevilo_sedezev                  NaN                  NaN          NaN
# Hitrost_max                      NaN                  NaN          NaN
# Leto_izdelave                    NaN                  NaN          NaN
#
#                           Moc  Stevilo_sedezev  Hitrost_max  Leto_izdelave
# Starost_vozinka      0.068173         0.017011     0.072182       0.135365
# Upravna_enota_sifra  0.038365         0.020637     0.020972       0.006156
# Masa_vozila          0.412120         0.161128     0.049158       0.067788
# Moc                       NaN         0.554610     0.733135       0.027786
# Stevilo_sedezev           NaN              NaN     0.666847       0.136521
# Hitrost_max               NaN              NaN          NaN       0.012056
# Leto_izdelave             NaN              NaN          NaN            NaN

# %% [markdown]
# S pomočjo `sns.lmplot` funkcije izrišite graf, ki prikazuje linearno regresijo med `Hitrost_max` in `Moc`.
#
# `2 pts`

# %%
df.head(3)
# Out:
#   Prva_registracija   Tablica_kraj  Starost_vozinka Spol_voznika  \
# 0        2007-10-24          KRSKO               61            M
# 1        2019-03-25  MURSKA SOBOTA               58            Z
# 2        2008-01-08          CELJE               71            M
#
#    Upravna_enota_sifra Znamka Država_proizvodnje  Masa_vozila  \
# 0                    2    BMW                DEU        223.0
# 1                   36   FIAT                ITA       1270.0
# 2                   59  HONDA                JPN        242.0
#
#   Kategorija_vozila   Moc  Gorivo  Stevilo_sedezev  Hitrost_max Poraba_goriva  \
# 0      motorno kolo  80.0  Bencin                2        215.0           NaN
# 1  osebni avtomobil  70.0  Bencin                5        185.0           7,7
# 2      motorno kolo  37.0  Bencin                2        160.0           NaN
#
#    Leto_izdelave  Upravna_enota
# 0           2007        BREŽICE
# 1           2019  MURSKA SOBOTA
# 2           2008        VELENJE

# %%
sns.lmplot(data=df, x='Hitrost_max', y='Moc')

# %%
# Odgovor
sns.heatmap(df_corr, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# Izpišite vrstico, kjer je vrednost `Moc` maksimalna.
#
# `2 pts`

# %%
# Odgovor
df.loc[df['Moc'].idxmax()]
# Out:
# Prva_registracija            2017-09-26
# Tablica_kraj                  LJUBLJANA
# Starost_vozinka                      69
# Spol_voznika                          M
# Upravna_enota_sifra                  44
# Znamka                             AUDI
# Država_proizvodnje                  DEU
# Masa_vozila                        2065
# Kategorija_vozila      osebni avtomobil
# Moc                                 445
# Gorivo                           Bencin
# Stevilo_sedezev                       5
# Hitrost_max                         305
# Poraba_goriva                        10
# Leto_izdelave                      2017
# Upravna_enota                RADOVLJICA
# Name: 1991, dtype: object

# %% [markdown]
# ## Oddaja
#
# Rešeni notebook pošljite na naslednja e-mail naslova:
# - leon.stefanic@ltfe.org
# - gregor.balkovec@ltfe.org
#
# **POMEMBNO!** Pred pošiljanjem notebook preimenujte na naslednji način:
#
# `IZPIT_PRAKSA_IME_PRIMEK`
